# %% [markdown]
# # Plotting Surface

# %% [markdown]
# We offer three function to plot brain surface data.
#
# - `draw_cortex` to draw cerebral cortex
# - `draw_subcortex_tian` to draw subcortex from atlas by Tian 2020[^1]
# - `draw_sftian` to draw cerebral cortex and subcortex in the same time.
#
#     [^1]: Tian, Y., Margulies, D. S., Breakspear, M., & Zalesky, A. (2020). Topographic organization of the human subcortex unveiled with functional connectivity gradients. Nature Neuroscience, 23(11), 1421–1432. https://doi.org/10.1038/s41593-020-00711-6

# %%
import numpy as np

from neurocat.plotting import draw_and_save as ds
from neurocat.plotting import draw_subcortex_tian as dst
from neurocat.plotting import draw_sftian_save as dsts

# %%
dsts(np.load('se_schaefer432_hcpya_group.npy'), color_range=[0.2, 0.22], legend='entropy')
